# %% [markdown]
# <a href="https://colab.research.google.com/github/msalmankhan03/Object-Detection/blob/main/YOLOv8_Video_Object_Detection_(Using_Public_COCO_Dataset_Classes).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab import files
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")   # downloads automatically

# %%
uploaded = files.upload()   # select your video
# Out:
#      <input type="file" id="files-529a8450-7685-463e-b0e2-63b278bd9152" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-529a8450-7685-463e-b0e2-63b278bd9152">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
input_video_path = list(uploaded.keys())[0]
print("Your uploaded video:", input_video_path)
# Out:
# Your uploaded video: example.mp4

# %%
import cv2

# Load video
cap = cv2.VideoCapture(input_video_path)

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)      # YOLO prediction
    annotated = results[0].plot()  # draw boxes

    out.write(annotated)

cap.release()
out.release()
print("Processing done! Output file saved as output.mp4")
# Out:
# 0: 640x384 1 bird, 71.8ms
# Speed: 16.5ms preprocess, 71.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 spoons, 2 bowls, 1 couch, 6.3ms
# Speed: 2.9ms preprocess, 6.3ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 spoon, 1 bowl, 1 bed, 1 dining table, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 couch, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 5.9ms
# Speed: 1.8ms preprocess, 5.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 spoon, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 umbrella, 11.1ms
# ...

# %%
files.download("output.mp4")
